# %%
filename = "ngram_input.txt"

with open(filename) as f:
    content = f.readlines()
content = [ line for line in content if line != '\n' ]
len(content)
# Out:
# 155

# %%
tokens = [t for l in content for t in l.split() ]

# %%
tl = len(tokens)

# %%
import nltk
freq = nltk.FreqDist(tokens)
probs = {k: v/tl for (k,v) in freq.items()}
pvals = list(probs.values())
cumprobs = {k: sum(pvals[0:ix+1]) for ix, (k,v) in enumerate(probs.items())}

# %%
cfd_bigram = nltk.ConditionalFreqDist(nltk.bigrams(tokens))

# %%
cfd_bigram.items()

# %%
trigrams = nltk.trigrams(tokens)
condition_pairs = (((w0, w1), w2) for w0, w1, w2 in trigrams)
cfd_trigram = nltk.ConditionalFreqDist(condition_pairs)

# %%
cfd_trigram.items()
# Out:
# dict_items([(('Towards', 'a'), FreqDist({'Framework': 1})), (('a', 'Framework'), FreqDist({'for': 2})), (('Framework', 'for'), FreqDist({'Understanding': 2})), (('for', 'Understanding'), FreqDist({'the': 2})), (('Understanding', 'the'), FreqDist({'Performance': 2})), (('the', 'Performance'), FreqDist({'of': 2})), (('Performance', 'of'), FreqDist({'Blockchains': 1, 'Blockchains,"': 1})), (('of', 'Blockchains'), FreqDist({'M.': 1})), (('Blockchains', 'M.'), FreqDist({'Touloupou,': 1})), (('M.', 'Touloupou,'), FreqDist({'K.': 1})), (('Touloupou,', 'K.'), FreqDist({'Christodoulou,': 1})), (('K.', 'Christodoulou,'), FreqDist({'A.': 1})), (('Christodoulou,', 'A.'), FreqDist({'Inglezakis,': 1})), (('A.', 'Inglezakis,'), FreqDist({'E.': 1})), (('Inglezakis,', 'E.'), FreqDist({'Iosif': 1})), (('E.', 'Iosif'), FreqDist({'and': 1})), (('Iosif', 'and'), FreqDist({'M.': 1})), (('and', 'M.'), FreqDist({'Themistocleous,': 1})), (('M.', 'Themistocleous,'), FreqDist({'"Towards': 1})), (('Themistocleous,', '"Towards'), FreqDist({'a': 1})), (('"Towards', 'a'), FreqDist({'Framework': 1})), (('of', 'Blockchains,"'), FreqDist({'2021': 1})), (('Blockchains,"', '2021'), FreqDist({'3rd': 1})), (('2021', '3rd'), FreqDist({'Conference': 2})), (('3rd', 'Conference'), FreqDist({'on': 2})), (('Conference', 'on'), FreqDist({'Blockchain': 3, 'Computer,': 1})), (('on', 'Blockchain'), FreqDist({'Research': 2, 'Technology': 2, 'Technology,"': 1, 'T.': 1, 'The': 1})), (('Blockchain', 'Research'), FreqDist({'&': 2})), (('Research', '&'), FreqDist({'Applications': 2})), (('&', 'Applications'), FreqDist({'for': 2})), (('Applications', 'for'), FreqDist({'Innovative': 2})), (('for', 'Innovative'), FreqDist({'Networks': 2})), (('Innovative', 'Networks'), FreqDist({'and': 2})), (('Networks', 'and'), FreqDist({'Services': 2})), (('and', 'Services'), FreqDist({'(BRAINS),': 2})), (('Services', '(BRAINS),'), FreqDist({'2021,': 2})), (('(BRAINS),', '2021,'), FreqDist({'pp.': 2})), (('2021,', 'pp.'), FreqDist({'47-48,': 1, '8-11,': 1, '410-414,': 1})), (('pp.', '47-48,'), FreqDist({'doi:': 1})), (('47-48,', 'doi:'), FreqDist({'10.1109/BRAINS52497.2021.9569810.': 1})), (('doi:', '10.1109/BRAINS52497.2021.9569810.'), FreqDist({'Abstract—': 1})), (('10.1109/BRAINS52497.2021.9569810.', 'Abstract—'), FreqDist({'Blockchain': 1})), (('Abstract—', 'Blockchain'), FreqDist({'and': 1})), (('Blockchain', 'and'), FreqDist({'Distributed': 1, 'Financial': 1})), (('and', 'Distributed'), FreqDist({'Ledger': 1})), (('Distributed', 'Ledger'), FreqDist({'Technology': 2})), (('Ledger', 'Technology'), FreqDist({'(DLT)': 1, '(DLT),': 1})), (('Technology', '(DLT)'), FreqDist({'appears': 1})), (('(DLT)', 'appears'), FreqDist({'to': 1})), (('appears', 'to'), FreqDist({'be': 1})), (('to', 'be'), FreqDist({'at': 1, 'explored': 1, 'an': 1, 'effective': 1, 'accessed': 1, 'one': 1, 'added,': 1, 'controlled.': 1, 'recorded,': 1, 'formulated': 1, ...})), (('be', 'at'), FreqDist({'a': 1})), (('at', 'a'), FreqDist({'worldwide': 1})), (('a', 'worldwide'), FreqDist({'threshold': 1})), (('worldwide', 'threshold'), FreqDist({'of': 1})), (('threshold', 'of'), FreqDist({'acceptance': 1})), (('of', 'acceptance'), FreqDist({'and': 1})), (('acceptance', 'and'), FreqDist({'adoption.': 1})), (('and', 'adoption.'), FreqDist({'Since': 1})), (('adoption.', 'Since'), FreqDist({'their': 1})), (('Since', 'their'), FreqDist({'inception,': 1})), (('their', 'inception,'), FreqDist({'several': 1})), (('inception,', 'several'), FreqDist({'innovative': 1})), (('several', 'innovative'), FreqDist({'projects': 1})), (('innovative', 'projects'), FreqDist({'have': 1})), (('projects', 'have'), FreqDist({'been': 1})), (('have', 'been'), FreqDist({'proposing': 1, 'tested': 1})), (('been', 'proposing'), FreqDist({'solutions': 1})), (('proposing', 'solutions'), FreqDist({'to': 1})), (('solutions', 'to'), FreqDist({'the': 1})), (('to', 'the'), FreqDist({'development': 2, 'blockchain': 1, 'ledger': 1, 'unique': 1, 'network': 1, 'fact': 1, 'cli ...
